# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
drknet = pd.read_csv('Darknet.csv')

# %%
drknet.dropna(inplace=True)

# %%
drknet.drop([35848, 89028], inplace=True)

# %%
drknet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141481 entries, 0 to 141529
# Data columns (total 85 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Flow ID                     141481 non-null  object
#  1   Src IP                      141481 non-null  object
#  2   Src Port                    141481 non-null  int64
#  3   Dst IP                      141481 non-null  object
#  4   Dst Port                    141481 non-null  int64
#  5   Protocol                    141481 non-null  int64
#  6   Timestamp                   141481 non-null  object
#  7   Flow Duration               141481 non-null  int64
#  8   Total Fwd Packet            141481 non-null  int64
#  9   Total Bwd packets           141481 non-null  int64
#  10  Total Length of Fwd Packet  141481 non-null  int64
#  11  Total Length of Bwd Packet  141481 non-null  int64
#  12  Fwd Packet Length Max       141481 non-null  int64
# ...

# %%
drknet.describe().T
# Out:
#                                count          mean           std          min  \
# Src Port                    141481.0  3.846160e+04  1.911700e+04     0.000000
# Dst Port                    141481.0  1.811475e+04  2.219805e+04     0.000000
# Protocol                    141481.0  1.035193e+01  5.432144e+00     0.000000
# Flow Duration               141481.0  2.081923e+07  3.809548e+07     0.000000
# Total Fwd Packet            141481.0  1.527972e+02  2.378644e+03     1.000000
# Total Bwd packets           141481.0  1.546077e+02  3.419151e+03     0.000000
# Total Length of Fwd Packet  141481.0  1.126601e+05  3.251919e+06     0.000000
# Total Length of Bwd Packet  141481.0  1.303924e+05  4.566800e+06     0.000000
# Fwd Packet Length Max       141481.0  2.089788e+02  6.495246e+02     0.000000
# Fwd Packet Length Min       141481.0  1.562249e+01  3.131637e+01     0.000000
# Fwd Packet Length Mean      141481.0  6.961815e+01  2.200003e+02     0.000000
# ...

# %%
drknet['Label'].unique()
# Out:
# array(['Non-Tor', 'NonVPN', 'Tor', 'VPN'], dtype=object)

# %%
no_t = len(drknet.loc[drknet['Label'] == 'Non-Tor'])
t = len(drknet.loc[drknet['Label'] == 'Tor'])
no_v = len(drknet.loc[drknet['Label'] == 'NonVPN'])
v = len(drknet.loc[drknet['Label'] == 'VPN'])

# %%
plt.bar(['Non-Tor', 'NonVPN', 'Tor', 'VPN'],[no_t, t, no_v, v])
# Out:
# <BarContainer object of 4 artists>

# %%
label_data=drknet['Label'].value_counts()
explode=(0.0,0.0,0.0,0.0)
plt.figure(figsize=(30,20))
patches, texts, pts= plt.pie(label_data,
                               labels=label_data.index,
                               colors=['blue','green','red','yellow'],
                               autopct='%1.1f%%',
                               textprops={'fontsize':25,
                                          'color':'black',
                                          'family':'serif'})
#plt.setp(pcts, color='black')
hfont={'fontname':'serif', 'weight':'bold'}
plt.title('traffic', size=20, **hfont)
centre_circle=plt.Circle((0,0),0.40, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %%
drknet['Label.1'].value_counts()
# Out:
# P2P                48520
# Browsing           32808
# Audio-Streaming    16580
# Chat               11473
# File-Transfer      11089
# Video-Streaming     9467
# Email               6143
# VOIP                3566
# AUDIO-STREAMING     1470
# Video-streaming      281
# File-transfer         84
# Name: Label.1, dtype: int64

# %%
data_val = [48520, 32808, 16580, 11473, 11089, 9467, 6143, 3566, 1470, 281, 84]
data_label = ['P2P', 'Browsing', 'Audio-Streaming', 'Chat', 'File-Transferring', 'Video-Transferring', 'Email', 'VOIP', 'AUDIO-STREAMING', 'VIDEO-Straming','FILE-Transfer']
plt.xticks(rotation=90)
plt.bar(data_label, data_val)
# Out:
# <BarContainer object of 11 artists>
